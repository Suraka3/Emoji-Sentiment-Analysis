# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d4b24c01-c2b6-447b-b78f-e4bb641cf916" name="files[]" multiple disabled />
#      <output id="result-d4b24c01-c2b6-447b-b78f-e4bb641cf916">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# !pip install emoji
# !pip install regex
# !pip install csv
# Out:
# Collecting emoji
#   Downloading https://files.pythonhosted.org/packages/9c/fb/7586e11ff9205c9be9d11d376fcb6990ec4bdfae0a35663fb1ada7e3c10f/emoji-0.5.1-py3-none-any.whl
# Installing collected packages: emoji
# Successfully installed emoji-0.5.1
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (2017.11.9)
# Collecting csv
#   Could not find a version that satisfies the requirement csv (from versions: )
# No matching distribution found for csv

# %%
tweet_file = "data/german_tweets_text_id_only_387627_samples.csv"
emoji_cnt_file = "data/emoji_cnt_from_387627_samples.csv"

# %%
import emoji
import regex
import csv

def split_count(text):

    emoji_list = []
    data = regex.findall(r'\X', text)
    for word in data:
        if any(char in emoji.UNICODE_EMOJI for char in word):
            emoji_list.append(word)

    return emoji_list
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-5de3ce051e5c> in <module>()
# ----> 1 import emoji
#       2 import regex
#       3 import csv
#       4
#       5 def split_count(text):
#
# ModuleNotFoundError: No module named 'emoji'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def count_emojis_in_tweets(tweet_file):
    emoji_cnt = {}
    with open(tweet_file, 'r', encoding='utf-8', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=';')
        i = 0
        for row in reader:
            if i == 0:
                i += 1
                continue
            #print(', '.join(row))
            line = [row[1]]
        
            counter = split_count(line[0])
            len(counter)
            unique_counter = {}
            for emoji in counter:
                unique_counter[emoji] = 1 
            for emoji in unique_counter:
                if emoji not in emoji_cnt:
                    emoji_cnt[emoji] = 0
                emoji_cnt[emoji] += 1    
            '''
            i += 1
            if i > 100:
                break;
            '''
    return emoji_cnt

# %%
def sort_emoji_count_by_value(emoji_cnt):
    sorted_by_value = sorted(emoji_cnt.items(), key=lambda kv: kv[1])
    sorted_by_value.reverse()
    return sorted_by_value

# %%
def display_emoji_count(emoji_cnt):
    for emoji_tuple in emoji_cnt:
        print(emoji_tuple[0]+": "+str(emoji_tuple[1]))

# %%
def write_emoji_count(emoji_cnt, emoji_cnt_file):
    with open(emoji_cnt_file, 'w', encoding='utf-8', newline='') as csvfile:
        writer = csv.writer(csvfile, delimiter=';', 
                            quoting=csv.QUOTE_MINIMAL)
        #writer.writeheader()
        writer.writerows(emoji_cnt)

# %%
emoji_cnt = count_emojis_in_tweets(tweet_file)
emoji_cnt = sort_emoji_count_by_value(emoji_cnt)

#write_emoji_count(emoji_cnt, emoji_cnt_file)
display_emoji_count(emoji_cnt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e72f2c2e5108> in <module>()
# ----> 1 emoji_cnt = count_emojis_in_tweets(tweet_file)
#       2 emoji_cnt = sort_emoji_count_by_value(emoji_cnt)
#       3
#       4 #write_emoji_count(emoji_cnt, emoji_cnt_file)
#       5 display_emoji_count(emoji_cnt)
#
# NameError: name 'tweet_file' is not defined

# %%
def count_emoticons_happy
for emoticons_happy in emoji_cnt_file
print (emoticons_happy)
# Out:
#   File "<ipython-input-10-b0c29c39378b>", line 1
#     def count_emoticons_happy
#                              ^
# SyntaxError: invalid syntax

# %%
def count_emoticons_sad
for  emoticons_sad in emoji_cnt_file
print (emoticons_sad)
# Out:
#   File "<ipython-input-11-3e8f0b47dcf2>", line 1
#     def count_emoticons_sad
#                            ^
# SyntaxError: invalid syntax

# %%
def count_emojies_pro_tweet

tweet_file = "data/german_tweets_text_id_only_387627_samples.csv"
emoji_cnt_file = "data/emoji_cnt_from_387627_samples.csv"
for s in  [emoji_cnt_file]:
  m = tweet_file.match(s)
  if m :
    print s 
    else :
      print 'not'
